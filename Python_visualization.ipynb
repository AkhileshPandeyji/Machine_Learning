# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#matches = pd.read_csv("ipl/matches.csv")
#matches.shape

# %%
#matches.head()
#matches[matches["player_of_match" = "MS Dhoni"]]

# %%
#matches[(matches["player_of_match" = "MS Dhoni"]) & (matches["win_by_wickets"]>3)]

# %%
#pd.value_counts(matches["winner"]) returns the frequency of matches_win of particular column

# %%
#matches.drop_duplicates('season',keep='last')[['season','winner']]

# %%
#deliveries = pd.read_csv("ipl/deliveries.csv")

# %%
#deliveries.shape

# %%
#deliveries.head()

# %%
#six_data = deliveries[deliveries['batsman_runs'] == 6]
#pd.value_counts(six_data['batsman']).head(10)

# %%
x = np.arange(1,100,10)

# %%
len(x)
# Out:
# 10

# %%
y = x**2

# %%
plt.plot(x,y) #line plot

# %%
plt.show()

# %%
plt.plot(x,y,'o') #scatter plot

# %%
x = np.random.randint(-1,90,10)

# %%
y = np.random.randint(-9,80,10)

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'o')

# %%
x = [23,45,15,15]
labels = ['AAP','BJP','RJD','CONG']

# %%
plt.pie(x,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x2422ac99080>,
#   <matplotlib.patches.Wedge at 0x2422ac995c0>,
#   <matplotlib.patches.Wedge at 0x2422ac99a90>,
#   <matplotlib.patches.Wedge at 0x2422ac99f60>],
#  [Text(0.8143057798261398, 0.7395309979586674, 'AAP'),
#   Text(-1.0724207066739067, 0.24477301300804977, 'BJP'),
#   Text(0.14066486221868738, -1.0909690172213864, 'RJD'),
#   Text(0.9752592345798634, -0.5087921239236112, 'CONG')])

# %%
plt.show()

# %%
plt.pie(x,labels=labels,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x2422acda2b0>,
#   <matplotlib.patches.Wedge at 0x2422acdaa58>,
#   <matplotlib.patches.Wedge at 0x2422af54208>,
#   <matplotlib.patches.Wedge at 0x2422af54978>],
#  [Text(0.8143057798261398, 0.7395309979586674, 'AAP'),
#   Text(-1.0724207066739067, 0.24477301300804977, 'BJP'),
#   Text(0.14066486221868738, -1.0909690172213864, 'RJD'),
#   Text(0.9752592345798634, -0.5087921239236112, 'CONG')])

# %%
#pd.value_counts(matches['toss_decision'])
#deli = deliveries.dropna(subset=['bowler','player_dismissal','dismissal_kind'])
#temp_df = deli[deli['dismissal_kind'] !='run_out']
#temp_df.head()
#pd.value_counts(temp_df['bowler'].head())

# %%
#pd.value_counts(temp_df['dismissal_kind'])
